# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
file = 'selatmalaka.nc4'
ds = Dataset(file)
print(ds)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z
#     field_type: instantaneous
#     Conventions: CF-1.6 NAVO_netcdf_v1.1
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = GLBu0.08/expt_91.2/ts3z; Translation Date = 2021-12-07T14:38:16.544Z
#     geospatial_lat_min: 0.47999998927116394
#     geospatial_lat_max: 5.519999980926514
#     geospatial_lon_min: 95.52001953125
#     geospatial_lon_max: 104.9599609375
#     dimensions(sizes): time(28), depth(40), lat(64), lon(119)
#     variables(dimensions): int16 salinity(time, depth, lat, lon), float64 time(time), float64 depth(depth), float64 lat(lat), float64 lon(lon)
#     groups:

# %%
salt = ds.variables['salinity'][0,0,:,:]
lats = ds.variables['lat'][:]
lons = ds.variables['lon'][:]
time = ds.variables['time'][:]
ds.close()

# %%
lon_0 = lons.mean()
lat_0 = lats.mean()
m = Basemap(projection='mill',lat_ts=10,
            llcrnrlon=95.5, urcrnrlon=105,
            llcrnrlat=0.5,urcrnrlat=5.5,
            resolution='h')
Lon, Lat = np.meshgrid(lons,lats)
x, y = m(Lon, Lat)

# %%
fig =plt.figure(figsize=(12,9))
m.drawcountries()
m.drawcoastlines()
m.drawmapboundary()
m.contourf(x,y,salt,cmap=plt.cm.jet)
b = m.colorbar()
b.set_label('Salinity',rotation=90)

meridians = np.arange(Lon.min(),Lon.max(),5)
parallels = np.arange(Lat.min(),Lat.max(),5)
plt.title('Salinity',fontsize=20)
m.drawparallels(np.arange(0.5, 5.5, 1), labels = [1, 0, 0, 0], linewidth =0.5, color = 'k')
m.drawmeridians(np.arange(95.5, 105, 1), labels = [0, 0, 0, 1], linewidth =0.5, color = 'k')
# Out:
# {95.5: ([<matplotlib.lines.Line2D at 0x26f8b5e2af0>],
#   [Text(1056.351305704471, -10563.51305704471, '95.5°E')]),
#  96.5: ([<matplotlib.lines.Line2D at 0x26f8b5ee760>],
#   [Text(111973.23840467393, -10563.51305704471, '96.5°E')]),
#  97.5: ([<matplotlib.lines.Line2D at 0x26f8b5eea30>],
#   [Text(222890.1255036434, -10563.51305704471, '97.5°E')]),
#  98.5: ([<matplotlib.lines.Line2D at 0x26f8b5eed00>],
#   [Text(333807.01260261284, -10563.51305704471, '98.5°E')]),
#  99.5: ([<matplotlib.lines.Line2D at 0x26f8b5fc040>],
#   [Text(445780.2510072868, -10563.51305704471, '99.5°E')]),
#  100.5: ([<matplotlib.lines.Line2D at 0x26f8b5fc2e0>],
#   [Text(556697.1381062563, -10563.51305704471, '100.5°E')]),
#  101.5: ([<matplotlib.lines.Line2D at 0x26f8b5fc5b0>],
#   [Text(667614.0252052257, -10563.51305704471, '101.5°E')]),
#  102.5: ([<matplotlib.lines.Line2D at 0x26f8b5fc880>],
#   [Text(778530.9123041952, -10563.51305704471, '102.5°E')]),
#  103.5: ([<matplotlib.lines.Line2D at 0x26f8b5fcb50>],
#   [Text(890504.1507088691, -10563.51305704471, '103.5°E')]),
#  104.5: ([<matplotlib.lines.Line2D at 0x26f8b5fce20>],
#   [Text(1001421.0378078386, -10563.51305704471, '104.5°E')])}

# %%
#plt.savefig('selatmalaka.PNG', bbox_inches = 'tight', dpi = 200, pad_inches = 0.5)

# %%
file = 'selatmakassar.nc4'
ds = Dataset(file)
print(ds)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z
#     field_type: instantaneous
#     Conventions: CF-1.6 NAVO_netcdf_v1.1
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = GLBu0.08/expt_91.2/ts3z; Translation Date = 2021-12-07T14:39:15.162Z
#     geospatial_lat_min: -2.9600000381469727
#     geospatial_lat_max: 1.0399999618530273
#     geospatial_lon_min: 116.0
#     geospatial_lon_max: 120.0
#     dimensions(sizes): time(28), depth(40), lat(51), lon(51)
#     variables(dimensions): int16 salinity(time, depth, lat, lon), float64 time(time), float64 depth(depth), float64 lat(lat), float64 lon(lon)
#     groups:

# %%
salt = ds.variables['salinity'][0,0,:,:]
lats = ds.variables['lat'][:]
lons = ds.variables['lon'][:]
time = ds.variables['time'][:]
ds.close()

# %%
lon_0 = lons.mean()
lat_0 = lats.mean()
m = Basemap(projection='mill',lat_ts=10,
            llcrnrlon=116, urcrnrlon=120.5,
            llcrnrlat=-3,urcrnrlat=1,
            resolution='h')
Lon, Lat = np.meshgrid(lons,lats)
x, y = m(Lon, Lat)

# %%
fig =plt.figure(figsize=(12,9))
m.drawcountries()
m.drawcoastlines()
m.drawmapboundary()
m.contourf(x,y,salt,cmap=plt.cm.jet)
b = m.colorbar()
b.set_label('Salinity',rotation=90)

meridians = np.arange(Lon.min(),Lon.max(),5)
parallels = np.arange(Lat.min(),Lat.max(),5)
plt.title('Salinity',fontsize=20)
m.drawparallels(np.arange(-3, 1, 1), labels = [1, 0, 0, 0], linewidth =0.5, color = 'k')
m.drawmeridians(np.arange(116, 120.5, 1), labels = [0, 0, 0, 1], linewidth =0.5, color = 'k')
# Out:
# {116.0: ([<matplotlib.lines.Line2D at 0x26f8b77be50>],
#   [Text(500.3769342810653, -5003.769342810654, '116°E')]),
#  117.0: ([<matplotlib.lines.Line2D at 0x26f8b412be0>],
#   [Text(111584.05634467756, -5003.769342810654, '117°E')]),
#  118.0: ([<matplotlib.lines.Line2D at 0x26f8b412eb0>],
#   [Text(222667.73575507407, -5003.769342810654, '118°E')]),
#  119.0: ([<matplotlib.lines.Line2D at 0x26f8b42a1c0>],
#   [Text(333751.41516547056, -5003.769342810654, '119°E')]),
#  120.0: ([<matplotlib.lines.Line2D at 0x26f8b42a490>],
#   [Text(444835.09457586706, -5003.769342810654, '120°E')])}

# %%
#plt.savefig('selatmakassar.PNG', bbox_inches = 'tight', dpi = 200, pad_inches = 0.5)

# %%
file = 'bob.nc4'
ds = Dataset(file)
print(ds)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z
#     field_type: instantaneous
#     Conventions: CF-1.6 NAVO_netcdf_v1.1
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = GLBu0.08/expt_91.2/ts3z; Translation Date = 2021-12-07T14:34:58.902Z
#     geospatial_lat_min: 5.519999980926514
#     geospatial_lat_max: 24.639999389648438
#     geospatial_lon_min: 78.1600341796875
#     geospatial_lon_max: 96.719970703125
#     dimensions(sizes): time(28), depth(40), lat(240), lon(233)
#     variables(dimensions): int16 salinity(time, depth, lat, lon), float64 time(time), float64 depth(depth), float64 lat(lat), float64 lon(lon)
#     groups:

# %%
salt = ds.variables['salinity'][0,0,:,:]
lats = ds.variables['lat'][:]
lons = ds.variables['lon'][:]
time = ds.variables['time'][:]
ds.close()

# %%
lon_0 = lons.mean()
lat_0 = lats.mean()
m = Basemap(projection='mill',lat_ts=10,
            llcrnrlon=78.2, urcrnrlon=96.7,
            llcrnrlat=5.5,urcrnrlat=24.6,
            resolution='h')
Lon, Lat = np.meshgrid(lons,lats)
x, y = m(Lon, Lat)

# %%
fig =plt.figure(figsize=(12,9))
m.drawcountries()
m.drawcoastlines()
m.drawmapboundary()
m.contourf(x,y,salt,cmap=plt.cm.jet)
b = m.colorbar()
b.set_label('Salinity',rotation=90)

meridians = np.arange(Lon.min(),Lon.max(),5)
parallels = np.arange(Lat.min(),Lat.max(),5)
plt.title('Salinity',fontsize=20)
m.drawparallels(np.arange(5.5, 24.6, 3), labels = [1, 0, 0, 0], linewidth =0.5, color = 'k')
m.drawmeridians(np.arange(78.2, 96.7, 3), labels = [0, 0, 0, 1], linewidth =0.5, color = 'k')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1380/2557480642.py in <module>
#       1 fig =plt.figure(figsize=(12,9))
# ----> 2 m.drawcountries()
#       3 m.drawcoastlines()
#       4 m.drawmapboundary()
#       5 m.contourf(x,y,salt,cmap=plt.cm.jet)
#
# D:\Miniconda\lib\site-packages\mpl_toolkits\basemap\__init__.py in drawcountries(self, linewidth, linestyle, color, antialiased, ax, zorder)
#    1908         self.set_axes_limits(ax=ax)
#    1909         # clip countries to map limbs
# -> 1910         countries,c = self._cliplimb(ax,countries)
#    1911         return countries
#    1912
#
# D:\Miniconda\lib\site-packages\mpl_toolkits\basemap\__init__.py in _cliplimb(self, ax, coll)
#    1819         c = self._mapboundarydrawn
#    1820         if c not in ax.patches:
# -> 1821             p = ax.add_patch(c)
#    1822             #p.set_clip_on(False)
#    1823         try:
#
# D:\Miniconda\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    2353         """
#    2354         self._deprecate_noninstance('add_patch', mpatches.Patch, p=p)
# -> 2355         self._set_artist_props(p)
#    2356         if p.get_clip_path() is None:
#    2357             p.set_clip_path(self.patch)
#
# D:\Miniconda\lib\site-packages\matplotlib\axes\_base.py in _set_artist_props(self, a)
#    1099     def _set_artist_props(self, a):
#    1100         """Set the boilerplate props for artists added to Axes."""
# -> 1101         a.set_figure(self.figure)
#    1102         if not a.is_transform_set():
#    1103             a.set_transform(self.transData)
#
# D:\Miniconda\lib\site-packages\matplotlib\artist.py in set_figure(self, fig)
#     738         # to more than one Axes
#     739         if self.figure is not None:
# --> 740             raise RuntimeError("Can not put single artist in "
#     741                                "more than one figure")
#     742         self.figure = fig
#
# RuntimeError: Can not put single artist in more than one figure
